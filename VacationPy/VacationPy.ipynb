# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID        City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0     ushuaia -54.8000  -68.3000      4.81        81          20
# 1        1  gola bazar  26.3431   83.3553     26.62        28          99
# 2        2       bluff -46.6000  168.3333     11.56        62          98
# 3        3     talnakh  69.4865   88.3972     -0.44        85         100
# 4        4    hermanus -34.4187   19.2345     14.88        84         100
#
#    Wind Speed Country        Date
# 0        0.51      AR  1682469867
# 1        0.35      IN  1682470035
# 2        7.89      NZ  1682469884
# 3        0.41      RU  1682469925
# 4        3.50      ZA  1682470036

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
city_data_map = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    color = "City"   
)

# Display the map
city_data_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
# Criteria: A max temperature lower than 27 degrees but higher than 2
#           Wind speed less than 4.5 m/s
#           Zero cloudiness

mask_1 = (city_data_df["Max Temp"]>2)&(city_data_df["Max Temp"]<27)
mask_2 = (city_data_df["Wind Speed"]<4.5)
mask_3 = (city_data_df["Cloudiness"]==0)

ideal_df = city_data_df.loc[mask_1&mask_2&mask_3,:]

# Drop any rows with null values
ideal_df = ideal_df.dropna(how="any")

# Display sample data
ideal_df
# Out:
#      City_ID                   City      Lat       Lng  Max Temp  Humidity  \
# 12        12             warrington  53.3925   -2.5802      6.55        73
# 77        77              cape town -33.9258   18.4232     17.17        78
# 88        88           saint george  37.1041 -113.5841     22.46        18
# 105      105                 gamovo  57.8652   56.1056      9.79        53
# 156      156                 bethel  41.3712  -73.4140     11.38        61
# 181      181                awjilah  29.1081   21.2869     20.12        32
# 188      188               erzincan  39.7500   39.5000      8.61        57
# 190      190                holland  42.7875  -86.1089      8.03        64
# 191      191            constantine  36.3650    6.6147     12.67        58
# 245      245                 bantva  21.4864   70.0689     25.34        76
# 250      250                manyana -23.4000   21.7167     18.80        43
# 262      262                  lampa -33.2833  -70.9000     20.18        59
# 313      313                 de aar -30.6497   24.0123     14.49        51
# 323      323          middle island  40.8843  -72.9373     12.13        72
# 331      331                   vite  17.2833   74.5500     22.52        72
# 338      338                 beloha -25.1667   45.0500     16.64        81
# 347      347           rio gallegos -51.6226  -69.2181      4.03        75
# 352      352              shancheng  34.7953  116.0817     16.99        57
# 388      388             zhezkazgan  47.8043   67.7144      3.99        65
# 394      394             quartucciu  39.2519    9.1794     17.80        79
# 402      402          pacific grove  36.6177 -121.9166     20.45        75
# 427      427                 baiyin  36.5583  104.2081     13.57        30
# 437      437                sederot  31.5250   34.5969     14.06        77
# 452      452                formosa -26.1775  -58.1781     18.99        98
# 468      468                   gasa  31.5000   34.4667     15.98        75
# 514      514        tsiroanomandidy -18.7667   46.0333     15.46        90
# 529      529               ajdabiya  30.7554   20.2263     18.29        38
# 537      537                 yushan  31.3776  120.9543     17.94        58
# 545      545           bloemfontein -29.1211   26.2140      8.71        81
# 560      560                    gat  31.6100   34.7642     16.33        78
# 565      565  los llanos de aridane  28.6585  -17.9182     16.86        77
# 578      578                 manama  26.2154   50.5832     24.99        73
# 585      585                 ingham  42.6000  -84.3833      6.57        75
# 593      593                   mayo  38.8876  -76.5119     13.06        66
#
#      Cloudiness  Wind Speed Country        Date
# 12            0        1.54      GB  1682469935
# 77            0        3.60      ZA  1682469658
# 88            0        4.02      US  1682469866
# 105           0        1.00      RU  1682470068
# 156           0        2.06      US  1682469792
# 181           0        3.95      LY  1682470090
# 188           0        4.12      TR  1682470094
# 190           0        4.47      US  1682470030
# 191           0        1.03      DZ  1682470094
# 245           0        2.62      IN  1682470111
# 250           0        3.71      BW  1682470113
# 262           0        3.09      CL  1682470117
# 313           0        1.38      ZA  1682470132
# 323           0        2.06      US  1682470135
# 331           0        2.96      IN  1682470139
# 338           0        1.80      MG  1682470141
# 347           0        3.60      AR  1682470144
# 352           0        3.01      CN  1682470146
# 388           0        4.00      KZ  1682470157
# 394           0        4.12      IT  1682470159
# 402           0        3.09      US  1682469749
# 427           0        1.67      CN  1682470170
# 437           0        1.26      IL  1682470173
# 452           0        1.54      AR  1682470093
# 468           0        1.44      PS  1682470183
# 514           0        1.34      MG  1682470198
# 529           0        2.08      LY  1682470203
# 537           0        2.66      CN  1682470206
# 545           0        0.51      ZA  1682470210
# 560           0        1.19      IL  1682470215
# 565           0        3.09      ES  1682469889
# 578           0        3.60      BH  1682469848
# 585           0        0.00      US  1682470042
# 593           0        1.54      US  1682470228

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = ideal_df[["City","Country","Lat","Lng","Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ""

# Display sample data
hotel_df
# Out:
#                       City Country      Lat       Lng  Humidity Hotel Name
# 12              warrington      GB  53.3925   -2.5802        73
# 77               cape town      ZA -33.9258   18.4232        78
# 88            saint george      US  37.1041 -113.5841        18
# 105                 gamovo      RU  57.8652   56.1056        53
# 156                 bethel      US  41.3712  -73.4140        61
# 181                awjilah      LY  29.1081   21.2869        32
# 188               erzincan      TR  39.7500   39.5000        57
# 190                holland      US  42.7875  -86.1089        64
# 191            constantine      DZ  36.3650    6.6147        58
# 245                 bantva      IN  21.4864   70.0689        76
# 250                manyana      BW -23.4000   21.7167        43
# 262                  lampa      CL -33.2833  -70.9000        59
# 313                 de aar      ZA -30.6497   24.0123        51
# 323          middle island      US  40.8843  -72.9373        72
# 331                   vite      IN  17.2833   74.5500        72
# 338                 beloha      MG -25.1667   45.0500        81
# 347           rio gallegos      AR -51.6226  -69.2181        75
# 352              shancheng      CN  34.7953  116.0817        57
# 388             zhezkazgan      KZ  47.8043   67.7144        65
# 394             quartucciu      IT  39.2519    9.1794        79
# 402          pacific grove      US  36.6177 -121.9166        75
# 427                 baiyin      CN  36.5583  104.2081        30
# 437                sederot      IL  31.5250   34.5969        77
# 452                formosa      AR -26.1775  -58.1781        98
# 468                   gasa      PS  31.5000   34.4667        75
# 514        tsiroanomandidy      MG -18.7667   46.0333        90
# 529               ajdabiya      LY  30.7554   20.2263        38
# 537                 yushan      CN  31.3776  120.9543        58
# 545           bloemfontein      ZA -29.1211   26.2140        81
# 560                    gat      IL  31.6100   34.7642        78
# 565  los llanos de aridane      ES  28.6585  -17.9182        77
# 578                 manama      BH  26.2154   50.5832        73
# 585                 ingham      US  42.6000  -84.3833        75
# 593                   mayo      US  38.8876  -76.5119        66

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000
params = {
    "categories":"accommodation.hotel",
    "apiKey": geoapify_key,
    "limit":20  
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    latitude = row["Lat"]
    longitude = row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# warrington - nearest hotel: Travelodge
# cape town - nearest hotel: Townhouse Hotel
# saint george - nearest hotel: The Advenire, an Autograph Collection Hotel
# gamovo - nearest hotel: Полёт
# bethel - nearest hotel: Hampton Inn Danbury
# awjilah - nearest hotel: No hotel found
# erzincan - nearest hotel: Kent Otel
# holland - nearest hotel: Haworth Hotel
# constantine - nearest hotel: Hôtel El Hawa Talk
# bantva - nearest hotel: No hotel found
# manyana - nearest hotel: No hotel found
# lampa - nearest hotel: No hotel found
# de aar - nearest hotel: No hotel found
# middle island - nearest hotel: Home2 Suites by Hilton Long Island Brookhaven
# vite - nearest hotel: No hotel found
# beloha - nearest hotel: Hôtel Oliv
# rio gallegos - nearest hotel: Amérian Río Gallegos Apart & Suites
# shancheng - nearest hotel: 如家酒店
# zhezkazgan - nearest hotel: KENGIR
# quartucciu - nearest hotel: Hotel hinterland
# pacific grove - nearest hotel: Pacific Grove Inn
# baiyin - nearest hotel: 红鹭宾馆
# sederot - nearest hotel: صالة ريفان
# formosa - nearest hotel: Hotel Hostal del Rey
# gasa - nearest hotel: مسجد الفتح المبين
# tsiroanomandidy - nearest hotel: Mega Food Hotel
# ajdabiya - nearest hotel: فندق المدينة
# yushan - nearest hotel: 大都会商务酒店
# bloemfontein - nearest hotel: Stadium Inn
# gat - nearest hotel: No hotel found
# los llanos de aridane - nearest hotel: Valle Aridane
# manama - nearest hotel: Hotel Mansouri Mansions
# ingham - nearest hotel: Comfort Inn
# mayo - nearest hotel: The Westin
#                       City Country      Lat       Lng  Humidity  \
# 12              warrington      GB  53.3925   -2.5802        73
# 77               cape town      ZA -33.9258   18.4232        78
# 88            saint george      US  37.1041 -113.5841        18
# 105                 gamovo      RU  57.8652   56.1056        53
# 156                 bethel      US  41.3712  -73.4140        61
# 181                awjilah      LY  29.1081   21.2869        32
# 188               erzincan      TR  39.7500   39.5000        57
# 190                holland      US  42.7875  -86.1089        64
# 191            constantine      DZ  36.3650    6.6147        58
# 245                 bantva      IN  21.4864   70.0689        76
# 250                manyana      BW -23.4000   21.7167        43
# 262                  lampa      CL -33.2833  -70.9000        59
# 313                 de aar      ZA -30.6497   24.0123        51
# 323          middle island      US  40.8843  -72.9373        72
# 331                   vite      IN  17.2833   74.5500        72
# 338                 beloha      MG -25.1667   45.0500        81
# 347           rio gallegos      AR -51.6226  -69.2181        75
# 352              shancheng      CN  34.7953  116.0817        57
# 388             zhezkazgan      KZ  47.8043   67.7144        65
# 394             quartucciu      IT  39.2519    9.1794        79
# 402          pacific grove      US  36.6177 -121.9166        75
# 427                 baiyin      CN  36.5583  104.2081        30
# 437                sederot      IL  31.5250   34.5969        77
# 452                formosa      AR -26.1775  -58.1781        98
# 468                   gasa      PS  31.5000   34.4667        75
# 514        tsiroanomandidy      MG -18.7667   46.0333        90
# 529               ajdabiya      LY  30.7554   20.2263        38
# 537                 yushan      CN  31.3776  120.9543        58
# 545           bloemfontein      ZA -29.1211   26.2140        81
# 560                    gat      IL  31.6100   34.7642        78
# 565  los llanos de aridane      ES  28.6585  -17.9182        77
# 578                 manama      BH  26.2154   50.5832        73
# 585                 ingham      US  42.6000  -84.3833        75
# 593                   mayo      US  38.8876  -76.5119        66
#
#                                         Hotel Name
# 12                                      Travelodge
# 77                                 Townhouse Hotel
# 88     The Advenire, an Autograph Collection Hotel
# 105                                          Полёт
# 156                            Hampton Inn Danbury
# 181                                 No hotel found
# 188                                      Kent Otel
# 190                                  Haworth Hotel
# 191                             Hôtel El Hawa Talk
# 245                                 No hotel found
# 250                                 No hotel found
# 262                                 No hotel found
# 313                                 No hotel found
# 323  Home2 Suites by Hilton Long Island Brookhaven
# 331                                 No hotel found
# 338                                     Hôtel Oliv
# 347            Amérian Río Gallegos Apart & Suites
# 352                                           如家酒店
# 388                                         KENGIR
# 394                               Hotel hinterland
# 402                              Pacific Grove Inn
# 427                                           红鹭宾馆
# 437                                     صالة ريفان
# 452                           Hotel Hostal del Rey
# 468                              مسجد الفتح المبين
# 514                                Mega Food Hotel
# 529                                   فندق المدينة
# 537                                        大都会商务酒店
# 545                                    Stadium Inn
# 560                                 No hotel found
# 565                                  Valle Aridane
# 578                        Hotel Mansouri Mansions
# 585                                    Comfort Inn
# 593                                     The Westin

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
hotel_map = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    scale = 1,
    color = "City",
    hover_cols = ["Hotel Name", "Country"]
)

# Display the map
hotel_map
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Hotel Name,Country)
